# %% [markdown]
# <a href="https://colab.research.google.com/github/DaveElPolaco/machine-learning-course/blob/main/supervised/01_basics/01_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### scikit-learn
# Strona biblioteki: [https://scikit-learn.org](https://scikit-learn.org)
#
# Dokumentacja/User Guide: [https://scikit-learn.org/stable/user_guide.html](https://scikit-learn.org/stable/user_guide.html)
#
# Podstawowa biblioteka do uczenia maszynowego w języku Python.
#
# Aby zainstalować bibliotekę scikit-learn, użyj polecenia poniżej:
# ```
# !pip install scikit-learn
# ```
# Aby zaktualizować do najnowszej wersji bibliotekę scikit-learn, użyj polecenia poniżej:
# ```
# !pip install --upgrade scikit-learn
# ```
# Kurs stworzony w oparciu o wersję `0.22.1`
#
# ### Preprocessing danych:
# 1. [Import bibliotek](#0)
# 2. [Wygenerowanie danych](#1)
# 3. [Utworzenie kopii danych](#2)
# 4. [Zmiana typu danych i wstępna eksploracja](#3)
# 5. [LabelEncoder](#4)
# 6. [OneHotEncoder](#5)
# 7. [Pandas *get_dummies()*](#6)
# 8. [Standaryzacja - StandardScaler](#7)
# 9. [Przygotowanie danych do modelu](#8)

# %% [markdown]
# ### <a name='0'></a> Import bibliotek

# %%
import numpy as np
import pandas as pd
import sklearn

print(sklearn.__version__)
# Out:
# 1.5.2

# %% [markdown]
# ### <a name='1'></a> Wygenerowanie danych

# %%
data = {
    'size': ['XL', 'L', 'M', 'L', 'M'],
    'color': ['red', 'green', 'blue', 'green', 'red'],
    'gender': ['female', 'male', 'male', 'female', 'female'],
    'price': [199.0, 89.0, 99.0, 129.0, 79.0],
    'weight': [500, 4504, 300, 380, 410],
    'bought': ['yes', 'no', 'yes', 'no', 'yes']
}

df_raw = pd.DataFrame(data=data)
df_raw
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0    4504     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %% [markdown]
# ### <a name='2'></a> Utworzenie kopii danych

# %%
df = df_raw.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      object
#  1   color   5 non-null      object
#  2   gender  5 non-null      object
#  3   price   5 non-null      float64
#  4   weight  5 non-null      int64
#  5   bought  5 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 368.0+ bytes

# %% [markdown]
# ### <a name='3'></a> Zmiana typu danych i wstępna eksploracja

# %%
for col in ['size', 'color', 'gender', 'bought']:
    df[col] = df[col].astype('category')

df['weight'] = df['weight'].astype('float')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   size    5 non-null      category
#  1   color   5 non-null      category
#  2   gender  5 non-null      category
#  3   price   5 non-null      float64
#  4   weight  5 non-null      float64
#  5   bought  5 non-null      category
# dtypes: category(4), float64(2)
# memory usage: 740.0 bytes

# %%
df.describe()
# Out:
#             price      weight
# count    5.000000     5.00000
# mean   119.000000  1218.80000
# std     48.476799  1837.87573
# min     79.000000   300.00000
# 25%     89.000000   380.00000
# 50%     99.000000   410.00000
# 75%    129.000000   500.00000
# max    199.000000  4504.00000

# %%
df.describe().T
# Out:
#         count    mean          std    min    25%    50%    75%     max
# price     5.0   119.0    48.476799   79.0   89.0   99.0  129.0   199.0
# weight    5.0  1218.8  1837.875730  300.0  380.0  410.0  500.0  4504.0

# %%
df.describe(include=['category']).T
# Out:
#        count unique     top freq
# size       5      3       M    2
# color      5      3     red    2
# gender     5      2  female    3
# bought     5      2     yes    3

# %%
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0   500.0    yes
# 1    L  green    male   89.0   450.0     no
# 2    M   blue    male   99.0   300.0    yes
# 3    L  green  female  129.0   380.0     no
# 4    M    red  female   79.0   410.0    yes

# %% [markdown]
# ### <a name='4'></a> LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(df['bought'])
le.transform(df['bought'])
# Out:
# array([1, 0, 1, 0, 1])

# %%
le.fit_transform(df['bought'])
# Out:
# array([1, 0, 1, 0, 1])

# %%
le.classes_
# Out:
# array([0, 1])

# %%
df['bought'] = le.fit_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0  4504.0       0
# 2    M   blue    male   99.0   300.0       1
# 3    L  green  female  129.0   380.0       0
# 4    M    red  female   79.0   410.0       1

# %%
le.inverse_transform(df['bought'])
# Out:
# array([1, 0, 1, 0, 1])

# %%
df['bought'] = le.inverse_transform(df['bought'])
df
# Out:
#   size  color  gender  price  weight  bought
# 0   XL    red  female  199.0   500.0       1
# 1    L  green    male   89.0  4504.0       0
# 2    M   blue    male   99.0   300.0       1
# 3    L  green  female  129.0   380.0       0
# 4    M    red  female   79.0   410.0       1

# %% [markdown]
# ### <a name='5'></a> OneHotEncoder

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(sparse_output=False)
encoder.fit(df[['size']])
# Out:
# OneHotEncoder(sparse_output=False)

# %%
encoder.transform(df[['size']])
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.],
#        [0., 1., 0.],
#        [1., 0., 0.],
#        [0., 1., 0.]])

# %%
encoder.categories_
# Out:
# [array(['L', 'M', 'XL'], dtype=object)]

# %%
encoder = OneHotEncoder(drop='first', sparse=False)
encoder.fit(df[['size']])
encoder.transform(df[['size']])
# Out:
# array([[0., 1.],
#        [0., 0.],
#        [1., 0.],
#        [0., 0.],
#        [1., 0.]])

# %%
df
# Out:
#   size  color  gender     price    weight  bought
# 0   XL    red  female  1.845062 -0.437267       1
# 1    L  green    male -0.691898  1.998484       0
# 2    M   blue    male -0.461266 -0.558933       1
# 3    L  green  female  0.230633 -0.510267       0
# 4    M    red  female -0.922531 -0.492017       1

# %% [markdown]
# ### <a name='6'></a> Pandas *get_dummies()*

# %%
pd.get_dummies(data=df)
# Out:
#    price  weight  bought  size_L  size_M  size_XL  color_blue  color_green  \
# 0  199.0   500.0       1   False   False     True       False        False
# 1   89.0  4504.0       0    True   False    False       False         True
# 2   99.0   300.0       1   False    True    False        True        False
# 3  129.0   380.0       0    True   False    False       False         True
# 4   79.0   410.0       1   False    True    False       False        False
#
#    color_red  gender_female  gender_male
# 0       True           True        False
# 1      False          False         True
# 2      False          False         True
# 3      False           True        False
# 4       True           True        False

# %%
pd.get_dummies(data=df, drop_first=True)
# Out:
#    price  weight  bought  size_M  size_XL  color_green  color_red  gender_male
# 0  199.0   500.0       1   False     True        False       True        False
# 1   89.0  4504.0       0   False    False         True      False         True
# 2   99.0   300.0       1    True    False        False      False         True
# 3  129.0   380.0       0   False    False         True      False        False
# 4   79.0   410.0       1    True    False        False       True        False

# %%
pd.get_dummies(data=df, drop_first=True, prefix='new')
# Out:
#    price  weight  bought  new_M  new_XL  new_green  new_red  new_male
# 0  199.0   500.0       1  False    True      False     True     False
# 1   89.0  4504.0       0  False   False       True    False      True
# 2   99.0   300.0       1   True   False      False    False      True
# 3  129.0   380.0       0  False   False       True    False     False
# 4   79.0   410.0       1   True   False      False     True     False

# %%
pd.get_dummies(data=df, drop_first=True, prefix_sep='-')
# Out:
#    price  weight  size-M  ...  color-red  gender-male  bought-yes
# 0  199.0   500.0       0  ...          1            0           1
# 1   89.0   450.0       0  ...          0            1           0
# 2   99.0   300.0       1  ...          0            1           1
# 3  129.0   380.0       0  ...          0            0           0
# 4   79.0   410.0       1  ...          1            0           1
#
# [5 rows x 8 columns]

# %%
pd.get_dummies(data=df, drop_first=True, columns=['size'])
# Out:
#    color  gender  price  weight  bought  size_M  size_XL
# 0    red  female  199.0   500.0       1   False     True
# 1  green    male   89.0  4504.0       0   False    False
# 2   blue    male   99.0   300.0       1    True    False
# 3  green  female  129.0   380.0       0   False    False
# 4    red  female   79.0   410.0       1    True    False

# %% [markdown]
# ### <a name='7'></a> Standaryzacja - StandardScaler
#
# std() - pandas nieobciążony
# std() - numpy obciążony

# %%
print(f"{df['price']}\n")
print(f"Średnia: {df['price'].mean()}")
print(f"Odchylenie standardowe: {df['price'].std():.4f}")
# Out:
# 0    199.0
# 1     89.0
# 2     99.0
# 3    129.0
# 4     79.0
# Name: price, dtype: float64
#
# Średnia: 119.0
# Odchylenie standardowe: 48.4768

# %%
(df['price'] - df['price'].mean()) / df['price'].std()
# Out:
# 0    1.650274
# 1   -0.618853
# 2   -0.412568
# 3    0.206284
# 4   -0.825137
# Name: price, dtype: float64

# %%
def standardize(x):
    return (x - x.mean()) / x.std()

standardize(df['price'])
# Out:
# 0    1.650274
# 1   -0.618853
# 2   -0.412568
# 3    0.206284
# 4   -0.825137
# Name: price, dtype: float64

# %%
from sklearn.preprocessing import scale

scale(df['price'])
# Out:
# array([ 1.84506242, -0.69189841, -0.4612656 ,  0.2306328 , -0.92253121])

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df[['price']])
scaler.transform(df[['price']])
# Out:
# array([[ 1.84506242],
#        [-0.69189841],
#        [-0.4612656 ],
#        [ 0.2306328 ],
#        [-0.92253121]])

# %%
scaler = StandardScaler()
df[['price', 'weight']] = scaler.fit_transform(df[['price', 'weight']])
df
# Out:
#   size  color  gender     price    weight  bought
# 0   XL    red  female  1.845062 -0.437267       1
# 1    L  green    male -0.691898  1.998484       0
# 2    M   blue    male -0.461266 -0.558933       1
# 3    L  green  female  0.230633 -0.510267       0
# 4    M    red  female -0.922531 -0.492017       1

# %% [markdown]
# ### <a name='8'></a> Przygotowanie danych do modelu

# %%
df = df_raw.copy()
df
# Out:
#   size  color  gender  price  weight bought
# 0   XL    red  female  199.0     500    yes
# 1    L  green    male   89.0    4504     no
# 2    M   blue    male   99.0     300    yes
# 3    L  green  female  129.0     380     no
# 4    M    red  female   79.0     410    yes

# %%
le = LabelEncoder()

df['bought'] = le.fit_transform(df['bought'])

scaler = StandardScaler()
df[['price', 'weight']] = scaler.fit_transform(df[['price', 'weight']])

df = pd.get_dummies(data=df, drop_first=True)
df
# Out:
#       price    weight  bought  size_M  size_XL  color_green  color_red  \
# 0  1.845062 -0.437267       1   False     True        False       True
# 1 -0.691898  1.998484       0   False    False         True      False
# 2 -0.461266 -0.558933       1    True    False        False      False
# 3  0.230633 -0.510267       0   False    False         True      False
# 4 -0.922531 -0.492017       1    True    False        False       True
#
#    gender_male
# 0        False
# 1         True
# 2         True
# 3        False
# 4        False
